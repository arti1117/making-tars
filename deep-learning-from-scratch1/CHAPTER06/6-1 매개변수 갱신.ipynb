# %%
from optimizer_compare_mnist import *
# Out:
# ===========iteration:0===========
# SGD:2.3423546257640746
# Momentum:2.4757551052390014
# AdaGrad:1.9802235525472045
# Adam:2.130925613528179
# ===========iteration:100===========
# SGD:1.6322637799812982
# Momentum:0.41910745881314887
# AdaGrad:0.20894817548388503
# Adam:0.31673412137676726
# ===========iteration:200===========
# SGD:0.8252864952582071
# Momentum:0.24826977937632355
# AdaGrad:0.11870378528835045
# Adam:0.18100739010305988
# ===========iteration:300===========
# SGD:0.5965578559873084
# Momentum:0.21176328416898688
# AdaGrad:0.05170044802410613
# Adam:0.1323232027174529
# ===========iteration:400===========
# SGD:0.4585383059621635
# Momentum:0.156991000345029
# AdaGrad:0.04044730822621022
# Adam:0.07367483610442667
# ===========iteration:500===========
# SGD:0.381390472663658
# Momentum:0.2267141582176624
# AdaGrad:0.04441473545396557
# Adam:0.11792737870268043
# ===========iteration:600===========
# SGD:0.33502150952535703
# Momentum:0.10629597639254271
# ...
