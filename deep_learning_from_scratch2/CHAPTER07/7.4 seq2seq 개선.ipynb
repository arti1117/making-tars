# %%
from train_seq2seq import *
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.57
# | 에폭 1 |  반복 21 / 351 | 시간 1[s] | 손실 2.48
# | 에폭 1 |  반복 41 / 351 | 시간 3[s] | 손실 2.20
# | 에폭 1 |  반복 61 / 351 | 시간 4[s] | 손실 1.99
# | 에폭 1 |  반복 81 / 351 | 시간 7[s] | 손실 1.89
# | 에폭 1 |  반복 101 / 351 | 시간 8[s] | 손실 1.82
# | 에폭 1 |  반복 121 / 351 | 시간 10[s] | 손실 1.82
# | 에폭 1 |  반복 141 / 351 | 시간 11[s] | 손실 1.80
# | 에폭 1 |  반복 161 / 351 | 시간 13[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 14[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 16[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 17[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 18[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 20[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 21[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 22[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 24[s] | 손실 1.73
# | 에폭 1 |  반복 341 / 351 | 시간 25[s] | 손실 1.73
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1013
# ---
# Q 582+84
# T 666
# ☒ 102
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 1023
# ---
# Q 600+257
# ...
