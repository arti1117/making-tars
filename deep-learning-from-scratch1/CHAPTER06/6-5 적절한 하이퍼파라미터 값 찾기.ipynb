# %%
from hyperparameter_optimization import *
# Out:
# val acc:0.79 | lr:0.007318558316397143, weight decay:8.834700628548797e-05
# val acc:0.1 | lr:4.556463781938946e-05, weight decay:1.4401427809450898e-05
# val acc:0.25 | lr:0.001744359094908219, weight decay:3.4065474610013045e-08
# val acc:0.8 | lr:0.007593440962661694, weight decay:5.7308023784028754e-08
# val acc:0.52 | lr:0.0029641901273654153, weight decay:1.9289350750094047e-05
# val acc:0.17 | lr:9.112554883696003e-05, weight decay:2.483451416079087e-07
# val acc:0.08 | lr:1.6915182796043474e-06, weight decay:1.4852440131514314e-05
# val acc:0.09 | lr:7.193963908391397e-06, weight decay:1.0994843904995038e-08
# val acc:0.13 | lr:0.0002521768688818499, weight decay:6.312056765970849e-08
# val acc:0.19 | lr:0.0005880588289239552, weight decay:6.285317760312916e-06
# val acc:0.05 | lr:0.0004501510326870027, weight decay:7.3782544224335455e-06
# val acc:0.1 | lr:5.139843367870707e-06, weight decay:9.211017543524243e-05
# ...
