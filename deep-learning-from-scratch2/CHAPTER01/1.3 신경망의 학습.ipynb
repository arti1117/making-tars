# %%
import numpy as np

D, N = 8, 7
x = np.random.randn(1, D)
y = np.repeat(x, N, axis=0)
y
# Out:
# array([[ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175],
#        [ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175],
#        [ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175],
#        [ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175],
#        [ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175],
#        [ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175],
#        [ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175]])

# %%
dy = np.random.randn(N, D)
dx = np.sum(dy,axis=0, keepdims=True)
dx
# Out:
# array([[-1.77673163, -2.86258485,  0.22083972,  2.19096245,  0.6690227 ,
#          2.55090643, -2.50414838,  0.07984755]])

# %%
x
# Out:
# array([[ 0.05412952, -1.55757504, -0.91294809, -1.22577446, -0.59705983,
#          0.99412012, -1.95473218, -0.35818175]])

# %%
dy
# Out:
# array([[-0.4086375 , -1.3537535 ,  0.14083884,  1.35884343,  0.15384912,
#          0.48101235,  0.46210564, -1.41128527],
#        [-0.95598744, -1.36799657, -1.56894393,  0.12270067, -0.14321971,
#         -0.93472494, -0.44838039,  0.36769885],
#        [-1.05734923, -0.53710406,  0.35400959, -0.25896402,  1.25645889,
#          0.28132788, -0.49159951,  0.46489872],
#        [-0.0579827 , -0.75395431,  0.33248638,  0.43644499, -1.82546393,
#          1.48110296, -1.21899416,  0.50828326],
#        [-0.58824543,  1.5204699 ,  1.55131922,  0.84705044, -0.41602918,
#          0.66365871,  0.45913636, -0.25938715],
#        [ 0.8150524 ,  0.11744973, -0.23090978,  0.3842791 ,  1.16294837,
#          0.6744603 , -0.72517517, -0.15882468],
#        [ 0.47641827, -0.48769605, -0.3579606 , -0.69939215,  0.48047915,
#         -0.09593084, -0.54124115,  0.56846383]])

# %%
x =np.random.randn(N, D)
x
# Out:
# array([[-1.40629532, -0.07353207,  0.65762276, -1.47170775, -0.79676886,
#         -0.42329465,  0.26972119,  0.44738263],
#        [-0.51126625,  0.30148094,  1.1601466 ,  0.58083964, -0.23987219,
#          0.92610706, -0.74570671,  0.07402376],
#        [ 1.95600889, -0.22993992, -0.16329578, -0.57111912,  0.49574465,
#         -0.04141611,  0.60070021,  0.64276631],
#        [ 1.45663162,  0.51922179, -0.47459034,  0.00946469, -0.86109376,
#          0.43484405,  0.15371229, -2.19639338],
#        [ 0.09997435,  1.47449536, -0.64839647,  1.05817996, -1.03442134,
#         -1.46142909,  0.46859807, -2.03587946],
#        [-1.97321706,  0.03207418,  1.42873785, -0.010348  ,  0.17417777,
#         -1.56777807, -0.65843991, -1.20586028],
#        [-0.57415989, -1.8448706 ,  1.54651869,  0.95220745, -0.9290308 ,
#          1.37973677,  0.32228641,  1.57776185]])

# %%
y = np.sum(x, axis=0, keepdims=True)
y
# Out:
# array([[-0.95232367,  0.17892969,  3.50674331,  0.54751688, -3.19126453,
#         -0.75323003,  0.41087155, -2.69619857]])

# %%
dy = np.random.randn(1, D)
dy
# Out:
# array([[ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518]])

# %%
dx = np.repeat(dy, N, axis=0)
dx
# Out:
# array([[ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518],
#        [ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518],
#        [ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518],
#        [ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518],
#        [ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518],
#        [ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518],
#        [ 0.83128526, -0.30624062,  0.22650088, -0.99825111,  0.67171647,
#          0.48094004,  0.79220854,  0.88542518]])
