# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
# !dot sample1.dot -T png -o sample1.png

# %%
sample1 = img.imread('sample1.png') 
plt.imshow(sample1)

# %%
# !dot sample2.dot -T png -o sample2.png

# %%
sample2 = img.imread('sample2.png') 
plt.imshow(sample2)

# %%
# !dot sample3.dot -T png -o sample3.png

# %%
sample3 = img.imread('sample3.png') 
plt.imshow(sample3)

# %%
# !dot sample4.dot -T png -o sample4.png

# %%
sample4 = img.imread('sample4.png') 
plt.imshow(sample4)
