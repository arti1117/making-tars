# %%
from weight_init_activation_histogram import *

# %%
from weight_init_compare import *
# Out:
# ===========iteration:0===========
# std=0.01:2.302552637607749
# Xavier:2.308190698182587
# He:2.372710388778812
# ===========iteration:100===========
# std=0.01:2.302624576097049
# Xavier:2.239332356252741
# He:1.3469431694977216
# ===========iteration:200===========
# std=0.01:2.3024220241268782
# Xavier:2.1559859602266536
# He:0.7737720331063284
# ===========iteration:300===========
# std=0.01:2.3007112933617737
# Xavier:1.802498649903677
# He:0.4405011146055427
# ===========iteration:400===========
# std=0.01:2.2998206636549954
# Xavier:1.253280794947515
# He:0.4600226807073723
# ===========iteration:500===========
# std=0.01:2.3028834092844956
# Xavier:0.831663730966942
# He:0.39486136744260214
# ===========iteration:600===========
# std=0.01:2.298698069339128
# Xavier:0.5069283349649405
# He:0.1966950213914627
# ===========iteration:700===========
# std=0.01:2.3016160486471744
# Xavier:0.5677953906427535
# He:0.29132281349223144
# ===========iteration:800===========
# ...
