# %%
t = [1, 2, 3]
x = iter(t)
next(x)
# Out:
# 1

# %%
next(x)
# Out:
# 2

# %%
next(x)
# Out:
# 3

# %%
next(x)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_11856/3485793935.py in <module>
# ----> 1 next(x)
#
# StopIteration:

# %%
class MyIterator:
    def __init__(self, max_cnt):
        self.max_cnt = max_cnt
        self.cnt = 0
        
    def __iter__(self):
        return self
    
    def __next__(self):
        if self.cnt == self.max_cnt:
            raise StopIteration()
            
        self.cnt += 1
        return self.cnt

# %%
obj = MyIterator(5)
for x in obj:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
import sys
sys.path.append('..')
import numpy as np
from dezero import *

# %%
from dezero.datasets import Spiral
from dezero.dataloaders import DataLoader

# %%
batch_size = 10
max_epoch = 1

# %%
train_set = Spiral(train=True)
test_set = Spiral(train=False)
train_loader = DataLoader(train_set, batch_size)
test_loader = DataLoader(test_set, batch_size, shuffle=False)

# %%
for epoch in range(max_epoch):
    for x, t in train_loader:
        print(x.shape, t.shape)
        break
        
    for x, t in test_loader:
        print(x.shape, t.shape)
        break
# Out:
# (10, 2) (10,)
# (10, 2) (10,)

# %%
import math
import numpy as np
import dezero
from dezero import optimizers
from dezero.models import MLP
from dezero import functions as F

# %%
max_epoch = 300
batch_size = 30
hidden_size = 10
lr = 1.0

# %%
model = MLP((hidden_size, 3))
optimizer = optimizers.SGD(lr).setup(model)

# %%
for epoch in range(max_epoch):
    sum_loss, sum_acc = 0, 0
    
    for x, t in train_loader:        
        y = model(x)
        loss = F.softmax_cross_entropy(y, t)
        acc = F.accuracy(y, t)
        
        model.cleargrads()
        loss.backward()
        optimizer.update()
        
        sum_loss += float(loss.data) * len(t)
        sum_acc += float(acc.data) * len(t)
        
    print('epoch %d, loss %.2f, accuracy %.4f' % 
          (epoch + 1, sum_loss / len(train_set), sum_acc / len(train_set)))
    
    sum_loss, sum_acc = 0, 0
    with dezero.no_grad():
        for x, t in test_loader:
            y = model(x)
            loss = F.softmax_cross_entropy(y, t)
            acc = F.accuracy(y, t)
            
            sum_loss += float(loss.data) * len(t)
            sum_acc += float(acc.data) * len(t)
    
    print('test loss %.2f, accuracy %.4f' % 
          (sum_loss / len(train_set), sum_acc / len(train_set)))
# Out:
# epoch 1, loss 1.07, accuracy 0.4000
# test loss 0.87, accuracy 0.4933
# epoch 2, loss 0.95, accuracy 0.4933
# test loss 1.05, accuracy 0.4700
# epoch 3, loss 0.82, accuracy 0.5733
# test loss 0.84, accuracy 0.5567
# epoch 4, loss 0.84, accuracy 0.5600
# test loss 0.79, accuracy 0.6167
# epoch 5, loss 0.81, accuracy 0.5500
# test loss 0.81, accuracy 0.6000
# epoch 6, loss 0.77, accuracy 0.5767
# test loss 0.79, accuracy 0.6167
# epoch 7, loss 0.77, accuracy 0.5833
# test loss 0.78, accuracy 0.5967
# epoch 8, loss 0.76, accuracy 0.5700
# test loss 0.86, accuracy 0.6000
# epoch 9, loss 0.75, accuracy 0.5867
# test loss 0.73, accuracy 0.5467
# epoch 10, loss 0.76, accuracy 0.5700
# test loss 0.73, accuracy 0.5867
# epoch 11, loss 0.74, accuracy 0.5867
# test loss 0.72, accuracy 0.6067
# epoch 12, loss 0.71, accuracy 0.6000
# test loss 0.90, accuracy 0.6100
# epoch 13, loss 0.72, accuracy 0.6200
# test loss 0.76, accuracy 0.6100
# epoch 14, loss 0.71, accuracy 0.6233
# test loss 0.72, accuracy 0.5900
# epoch 15, loss 0.69, accuracy 0.6333
# test loss 0.70, accuracy 0.6733
# epoch 16, loss 0.69, accuracy 0.6300
# test loss 0.67, accuracy 0.6300
# epoch 17, loss 0.70, accuracy 0.6167
# test loss 0.69, accuracy 0.6533
# epoch 18, loss 0.66, accuracy 0.6467
# test loss 0.65, accuracy 0.6133
# epoch 19, loss 0.64, accuracy 0.6367
# test loss 0.67, accuracy 0.6533
# epoch 20, loss 0.62, accuracy 0.6567
# test loss 0.61, accuracy 0.6700
# epoch 21, loss 0.63, accuracy 0.6433
# test loss 0.65, accuracy 0.7300
# epoch 22, loss 0.59, accuracy 0.6767
# test loss 0.62, accuracy 0.7567
# epoch 23, loss 0.57, accuracy 0.7300
# test loss 0.56, accuracy 0.7567
# epoch 24, loss 0.55, accuracy 0.7267
# test loss 0.52, accuracy 0.7233
# epoch 25, loss 0.52, accuracy 0.7433
# test loss 0.52, accuracy 0.7733
# epoch 26, loss 0.48, accuracy 0.7567
# test loss 0.47, accuracy 0.7633
# epoch 27, loss 0.46, accuracy 0.8033
# test loss 0.47, accuracy 0.8100
# epoch 28, loss 0.44, accuracy 0.8067
# test loss 0.42, accuracy 0.7933
# epoch 29, loss 0.42, accuracy 0.8067
# test loss 0.40, accuracy 0.8400
# epoch 30, loss 0.39, accuracy 0.8267
# test loss 0.39, accuracy 0.8633
# epoch 31, loss 0.38, accuracy 0.8467
# test loss 0.42, accuracy 0.8233
# epoch 32, loss 0.34, accuracy 0.8600
# test loss 0.34, accuracy 0.8467
# epoch 33, loss 0.34, accuracy 0.8833
# test loss 0.35, accuracy 0.8467
# epoch 34, loss 0.31, accuracy 0.8867
# test loss 0.31, accuracy 0.8767
# epoch 35, loss 0.31, accuracy 0.8867
# test loss 0.30, accuracy 0.8700
# epoch 36, loss 0.29, accuracy 0.9000
# test loss 0.32, accuracy 0.8900
# epoch 37, loss 0.29, accuracy 0.8767
# test loss 0.33, accuracy 0.8633
# epoch 38, loss 0.27, accuracy 0.8833
# test loss 0.28, accuracy 0.8867
# epoch 39, loss 0.26, accuracy 0.9133
# test loss 0.27, accuracy 0.8900
# epoch 40, loss 0.24, accuracy 0.9333
# test loss 0.29, accuracy 0.8733
# epoch 41, loss 0.24, accuracy 0.9133
# test loss 0.26, accuracy 0.8833
# epoch 42, loss 0.24, accuracy 0.9100
# test loss 0.24, accuracy 0.8933
# epoch 43, loss 0.23, accuracy 0.9233
# test loss 0.25, accuracy 0.9000
# epoch 44, loss 0.22, accuracy 0.9167
# test loss 0.23, accuracy 0.9100
# epoch 45, loss 0.22, accuracy 0.9300
# test loss 0.25, accuracy 0.9033
# epoch 46, loss 0.21, accuracy 0.9300
# test loss 0.22, accuracy 0.9267
# epoch 47, loss 0.21, accuracy 0.9233
# test loss 0.23, accuracy 0.9000
# epoch 48, loss 0.21, accuracy 0.9167
# test loss 0.22, accuracy 0.9133
# epoch 49, loss 0.20, accuracy 0.9233
# test loss 0.23, accuracy 0.9333
# epoch 50, loss 0.20, accuracy 0.9233
# test loss 0.21, accuracy 0.9233
# epoch 51, loss 0.19, accuracy 0.9233
# test loss 0.21, accuracy 0.9233
# epoch 52, loss 0.19, accuracy 0.9300
# test loss 0.21, accuracy 0.9067
# epoch 53, loss 0.19, accuracy 0.9267
# test loss 0.20, accuracy 0.9200
# epoch 54, loss 0.18, accuracy 0.9500
# test loss 0.20, accuracy 0.9333
# epoch 55, loss 0.18, accuracy 0.9300
# test loss 0.20, accuracy 0.9267
# epoch 56, loss 0.18, accuracy 0.9300
# test loss 0.21, accuracy 0.9067
# epoch 57, loss 0.18, accuracy 0.9267
# test loss 0.22, accuracy 0.8933
# epoch 58, loss 0.18, accuracy 0.9367
# test loss 0.19, accuracy 0.9300
# epoch 59, loss 0.17, accuracy 0.9300
# test loss 0.21, accuracy 0.9267
# epoch 60, loss 0.18, accuracy 0.9267
# test loss 0.19, accuracy 0.9333
# epoch 61, loss 0.16, accuracy 0.9433
# test loss 0.19, accuracy 0.9100
# epoch 62, loss 0.17, accuracy 0.9300
# test loss 0.19, accuracy 0.9400
# epoch 63, loss 0.16, accuracy 0.9367
# test loss 0.20, accuracy 0.9367
# epoch 64, loss 0.16, accuracy 0.9500
# test loss 0.21, accuracy 0.9100
# epoch 65, loss 0.15, accuracy 0.9400
# test loss 0.21, accuracy 0.9367
# epoch 66, loss 0.16, accuracy 0.9367
# test loss 0.19, accuracy 0.9167
# epoch 67, loss 0.16, accuracy 0.9233
# test loss 0.19, accuracy 0.9067
# epoch 68, loss 0.15, accuracy 0.9467
# test loss 0.18, accuracy 0.9233
# epoch 69, loss 0.16, accuracy 0.9267
# test loss 0.19, accuracy 0.9133
# epoch 70, loss 0.16, accuracy 0.9333
# test loss 0.18, accuracy 0.9367
# epoch 71, loss 0.14, accuracy 0.9567
# test loss 0.17, accuracy 0.9333
# epoch 72, loss 0.15, accuracy 0.9300
# test loss 0.19, accuracy 0.9333
# epoch 73, loss 0.15, accuracy 0.9333
# test loss 0.17, accuracy 0.9433
# epoch 74, loss 0.16, accuracy 0.9200
# test loss 0.17, accuracy 0.9300
# epoch 75, loss 0.15, accuracy 0.9467
# test loss 0.21, accuracy 0.9000
# epoch 76, loss 0.15, accuracy 0.9467
# test loss 0.17, accuracy 0.9300
# epoch 77, loss 0.15, accuracy 0.9500
# test loss 0.17, accuracy 0.9433
# epoch 78, loss 0.14, accuracy 0.9467
# test loss 0.17, accuracy 0.9433
# epoch 79, loss 0.14, accuracy 0.9400
# test loss 0.17, accuracy 0.9433
# epoch 80, loss 0.14, accuracy 0.9333
# test loss 0.19, accuracy 0.9333
# epoch 81, loss 0.14, accuracy 0.9500
# test loss 0.16, accuracy 0.9500
# epoch 82, loss 0.14, accuracy 0.9500
# test loss 0.16, accuracy 0.9433
# epoch 83, loss 0.14, accuracy 0.9367
# test loss 0.18, accuracy 0.9100
# epoch 84, loss 0.14, accuracy 0.9500
# test loss 0.18, accuracy 0.9200
# epoch 85, loss 0.15, accuracy 0.9200
# test loss 0.17, accuracy 0.9433
# epoch 86, loss 0.13, accuracy 0.9600
# test loss 0.19, accuracy 0.9367
# epoch 87, loss 0.14, accuracy 0.9333
# test loss 0.16, accuracy 0.9433
# epoch 88, loss 0.14, accuracy 0.9467
# test loss 0.18, accuracy 0.9067
# epoch 89, loss 0.13, accuracy 0.9500
# test loss 0.17, accuracy 0.9133
# epoch 90, loss 0.14, accuracy 0.9300
# test loss 0.16, accuracy 0.9433
# epoch 91, loss 0.14, accuracy 0.9300
# test loss 0.15, accuracy 0.9500
# epoch 92, loss 0.13, accuracy 0.9533
# test loss 0.16, accuracy 0.9467
# epoch 93, loss 0.12, accuracy 0.9500
# test loss 0.18, accuracy 0.9100
# epoch 94, loss 0.13, accuracy 0.9567
# test loss 0.16, accuracy 0.9500
# epoch 95, loss 0.13, accuracy 0.9467
# test loss 0.16, accuracy 0.9400
# epoch 96, loss 0.13, accuracy 0.9500
# test loss 0.17, accuracy 0.9433
# epoch 97, loss 0.12, accuracy 0.9500
# test loss 0.16, accuracy 0.9467
# epoch 98, loss 0.12, accuracy 0.9667
# test loss 0.15, accuracy 0.9500
# epoch 99, loss 0.12, accuracy 0.9600
# test loss 0.18, accuracy 0.9400
# epoch 100, loss 0.13, accuracy 0.9367
# test loss 0.15, accuracy 0.9533
# epoch 101, loss 0.12, accuracy 0.9567
# test loss 0.15, accuracy 0.9500
# epoch 102, loss 0.13, accuracy 0.9367
# test loss 0.15, accuracy 0.9467
# epoch 103, loss 0.12, accuracy 0.9500
# test loss 0.15, accuracy 0.9500
# epoch 104, loss 0.12, accuracy 0.9533
# test loss 0.16, accuracy 0.9200
# epoch 105, loss 0.12, accuracy 0.9400
# test loss 0.15, accuracy 0.9400
# epoch 106, loss 0.12, accuracy 0.9500
# test loss 0.15, accuracy 0.9433
# epoch 107, loss 0.12, accuracy 0.9467
# test loss 0.16, accuracy 0.9533
# epoch 108, loss 0.12, accuracy 0.9500
# test loss 0.14, accuracy 0.9533
# epoch 109, loss 0.12, accuracy 0.9600
# test loss 0.15, accuracy 0.9433
# epoch 110, loss 0.12, accuracy 0.9367
# test loss 0.15, accuracy 0.9567
# epoch 111, loss 0.12, accuracy 0.9500
# test loss 0.15, accuracy 0.9367
# epoch 112, loss 0.11, accuracy 0.9533
# test loss 0.15, accuracy 0.9433
# epoch 113, loss 0.12, accuracy 0.9500
# test loss 0.15, accuracy 0.9467
# epoch 114, loss 0.11, accuracy 0.9467
# test loss 0.15, accuracy 0.9433
# epoch 115, loss 0.12, accuracy 0.9633
# test loss 0.14, accuracy 0.9567
# epoch 116, loss 0.12, accuracy 0.9533
# test loss 0.16, accuracy 0.9200
# epoch 117, loss 0.12, accuracy 0.9400
# test loss 0.14, accuracy 0.9633
# epoch 118, loss 0.12, accuracy 0.9433
# test loss 0.14, accuracy 0.9500
# epoch 119, loss 0.11, accuracy 0.9567
# test loss 0.14, accuracy 0.9533
# epoch 120, loss 0.11, accuracy 0.9633
# test loss 0.15, accuracy 0.9500
# epoch 121, loss 0.11, accuracy 0.9567
# test loss 0.15, accuracy 0.9467
# epoch 122, loss 0.11, accuracy 0.9567
# test loss 0.14, accuracy 0.9467
# epoch 123, loss 0.12, accuracy 0.9633
# test loss 0.15, accuracy 0.9433
# epoch 124, loss 0.12, accuracy 0.9533
# test loss 0.14, accuracy 0.9467
# epoch 125, loss 0.11, accuracy 0.9633
# test loss 0.16, accuracy 0.9400
# epoch 126, loss 0.11, accuracy 0.9500
# test loss 0.14, accuracy 0.9533
# epoch 127, loss 0.12, accuracy 0.9500
# test loss 0.14, accuracy 0.9500
# epoch 128, loss 0.11, accuracy 0.9600
# test loss 0.15, accuracy 0.9500
# epoch 129, loss 0.11, accuracy 0.9500
# test loss 0.14, accuracy 0.9533
# epoch 130, loss 0.11, accuracy 0.9567
# test loss 0.16, accuracy 0.9233
# epoch 131, loss 0.10, accuracy 0.9600
# test loss 0.17, accuracy 0.9100
# epoch 132, loss 0.11, accuracy 0.9567
# test loss 0.14, accuracy 0.9533
# epoch 133, loss 0.10, accuracy 0.9567
# test loss 0.17, accuracy 0.9400
# epoch 134, loss 0.11, accuracy 0.9500
# test loss 0.16, accuracy 0.9267
# epoch 135, loss 0.11, accuracy 0.9567
# test loss 0.14, accuracy 0.9467
# epoch 136, loss 0.10, accuracy 0.9733
# test loss 0.16, accuracy 0.9500
# epoch 137, loss 0.11, accuracy 0.9567
# test loss 0.14, accuracy 0.9533
# epoch 138, loss 0.11, accuracy 0.9500
# test loss 0.14, accuracy 0.9567
# epoch 139, loss 0.11, accuracy 0.9600
# test loss 0.15, accuracy 0.9433
# epoch 140, loss 0.11, accuracy 0.9600
# test loss 0.13, accuracy 0.9567
# epoch 141, loss 0.10, accuracy 0.9633
# test loss 0.15, accuracy 0.9467
# epoch 142, loss 0.12, accuracy 0.9567
# test loss 0.14, accuracy 0.9500
# epoch 143, loss 0.11, accuracy 0.9567
# test loss 0.13, accuracy 0.9533
# epoch 144, loss 0.10, accuracy 0.9633
# test loss 0.17, accuracy 0.9200
# epoch 145, loss 0.11, accuracy 0.9533
# test loss 0.13, accuracy 0.9600
# epoch 146, loss 0.11, accuracy 0.9500
# test loss 0.14, accuracy 0.9567
# epoch 147, loss 0.10, accuracy 0.9733
# test loss 0.14, accuracy 0.9533
# epoch 148, loss 0.10, accuracy 0.9700
# test loss 0.13, accuracy 0.9633
# epoch 149, loss 0.10, accuracy 0.9700
# test loss 0.14, accuracy 0.9500
# epoch 150, loss 0.10, accuracy 0.9567
# test loss 0.17, accuracy 0.9200
# epoch 151, loss 0.10, accuracy 0.9633
# test loss 0.13, accuracy 0.9633
# epoch 152, loss 0.10, accuracy 0.9600
# test loss 0.16, accuracy 0.9233
# epoch 153, loss 0.10, accuracy 0.9600
# test loss 0.14, accuracy 0.9567
# epoch 154, loss 0.11, accuracy 0.9600
# test loss 0.14, accuracy 0.9500
# epoch 155, loss 0.09, accuracy 0.9700
# test loss 0.14, accuracy 0.9533
# epoch 156, loss 0.10, accuracy 0.9600
# test loss 0.13, accuracy 0.9533
# epoch 157, loss 0.10, accuracy 0.9600
# test loss 0.13, accuracy 0.9533
# epoch 158, loss 0.09, accuracy 0.9667
# test loss 0.14, accuracy 0.9633
# epoch 159, loss 0.10, accuracy 0.9567
# test loss 0.14, accuracy 0.9500
# epoch 160, loss 0.10, accuracy 0.9567
# test loss 0.14, accuracy 0.9400
# epoch 161, loss 0.10, accuracy 0.9567
# test loss 0.13, accuracy 0.9467
# epoch 162, loss 0.09, accuracy 0.9833
# test loss 0.13, accuracy 0.9567
# epoch 163, loss 0.10, accuracy 0.9667
# test loss 0.13, accuracy 0.9600
# epoch 164, loss 0.10, accuracy 0.9567
# test loss 0.13, accuracy 0.9533
# epoch 165, loss 0.10, accuracy 0.9567
# test loss 0.15, accuracy 0.9367
# epoch 166, loss 0.10, accuracy 0.9500
# test loss 0.12, accuracy 0.9533
# epoch 167, loss 0.10, accuracy 0.9567
# test loss 0.13, accuracy 0.9533
# epoch 168, loss 0.10, accuracy 0.9600
# test loss 0.14, accuracy 0.9467
# epoch 169, loss 0.10, accuracy 0.9533
# test loss 0.13, accuracy 0.9567
# epoch 170, loss 0.10, accuracy 0.9533
# test loss 0.14, accuracy 0.9533
# epoch 171, loss 0.10, accuracy 0.9600
# test loss 0.14, accuracy 0.9400
# epoch 172, loss 0.10, accuracy 0.9633
# test loss 0.12, accuracy 0.9667
# epoch 173, loss 0.09, accuracy 0.9667
# test loss 0.15, accuracy 0.9367
# epoch 174, loss 0.09, accuracy 0.9600
# test loss 0.13, accuracy 0.9600
# epoch 175, loss 0.09, accuracy 0.9700
# test loss 0.13, accuracy 0.9500
# epoch 176, loss 0.09, accuracy 0.9700
# test loss 0.15, accuracy 0.9267
# epoch 177, loss 0.09, accuracy 0.9633
# test loss 0.14, accuracy 0.9467
# epoch 178, loss 0.10, accuracy 0.9700
# test loss 0.16, accuracy 0.9267
# epoch 179, loss 0.10, accuracy 0.9600
# test loss 0.13, accuracy 0.9533
# epoch 180, loss 0.10, accuracy 0.9567
# test loss 0.13, accuracy 0.9533
# epoch 181, loss 0.09, accuracy 0.9667
# test loss 0.16, accuracy 0.9433
# epoch 182, loss 0.10, accuracy 0.9567
# test loss 0.14, accuracy 0.9600
# epoch 183, loss 0.09, accuracy 0.9633
# test loss 0.15, accuracy 0.9300
# epoch 184, loss 0.09, accuracy 0.9767
# test loss 0.12, accuracy 0.9633
# epoch 185, loss 0.09, accuracy 0.9633
# test loss 0.15, accuracy 0.9333
# epoch 186, loss 0.09, accuracy 0.9633
# test loss 0.13, accuracy 0.9633
# epoch 187, loss 0.09, accuracy 0.9600
# test loss 0.12, accuracy 0.9633
# epoch 188, loss 0.09, accuracy 0.9667
# test loss 0.14, accuracy 0.9467
# epoch 189, loss 0.10, accuracy 0.9500
# test loss 0.15, accuracy 0.9467
# epoch 190, loss 0.09, accuracy 0.9667
# test loss 0.12, accuracy 0.9700
# epoch 191, loss 0.10, accuracy 0.9533
# test loss 0.12, accuracy 0.9667
# epoch 192, loss 0.09, accuracy 0.9667
# test loss 0.13, accuracy 0.9600
# epoch 193, loss 0.09, accuracy 0.9700
# test loss 0.12, accuracy 0.9600
# epoch 194, loss 0.09, accuracy 0.9600
# test loss 0.14, accuracy 0.9500
# epoch 195, loss 0.09, accuracy 0.9600
# test loss 0.13, accuracy 0.9500
# epoch 196, loss 0.09, accuracy 0.9633
# test loss 0.13, accuracy 0.9633
# epoch 197, loss 0.09, accuracy 0.9633
# test loss 0.14, accuracy 0.9400
# epoch 198, loss 0.10, accuracy 0.9533
# test loss 0.14, accuracy 0.9467
# epoch 199, loss 0.08, accuracy 0.9667
# test loss 0.11, accuracy 0.9633
# epoch 200, loss 0.09, accuracy 0.9700
# test loss 0.13, accuracy 0.9567
# epoch 201, loss 0.10, accuracy 0.9633
# test loss 0.13, accuracy 0.9467
# epoch 202, loss 0.10, accuracy 0.9633
# test loss 0.12, accuracy 0.9600
# epoch 203, loss 0.09, accuracy 0.9700
# test loss 0.13, accuracy 0.9433
# epoch 204, loss 0.08, accuracy 0.9600
# test loss 0.13, accuracy 0.9600
# epoch 205, loss 0.09, accuracy 0.9667
# test loss 0.13, accuracy 0.9567
# epoch 206, loss 0.09, accuracy 0.9600
# test loss 0.12, accuracy 0.9667
# epoch 207, loss 0.09, accuracy 0.9600
# test loss 0.13, accuracy 0.9467
# epoch 208, loss 0.09, accuracy 0.9733
# test loss 0.12, accuracy 0.9633
# epoch 209, loss 0.08, accuracy 0.9667
# test loss 0.14, accuracy 0.9467
# epoch 210, loss 0.10, accuracy 0.9533
# test loss 0.12, accuracy 0.9533
# epoch 211, loss 0.07, accuracy 0.9867
# test loss 0.17, accuracy 0.9333
# epoch 212, loss 0.09, accuracy 0.9667
# test loss 0.13, accuracy 0.9500
# epoch 213, loss 0.09, accuracy 0.9633
# test loss 0.11, accuracy 0.9667
# epoch 214, loss 0.09, accuracy 0.9633
# test loss 0.17, accuracy 0.9367
# epoch 215, loss 0.09, accuracy 0.9533
# test loss 0.12, accuracy 0.9667
# epoch 216, loss 0.08, accuracy 0.9700
# test loss 0.12, accuracy 0.9633
# epoch 217, loss 0.08, accuracy 0.9667
# test loss 0.12, accuracy 0.9567
# epoch 218, loss 0.09, accuracy 0.9600
# test loss 0.14, accuracy 0.9533
# epoch 219, loss 0.09, accuracy 0.9667
# test loss 0.13, accuracy 0.9600
# epoch 220, loss 0.09, accuracy 0.9667
# test loss 0.12, accuracy 0.9633
# epoch 221, loss 0.08, accuracy 0.9700
# test loss 0.11, accuracy 0.9700
# epoch 222, loss 0.08, accuracy 0.9667
# test loss 0.12, accuracy 0.9633
# epoch 223, loss 0.08, accuracy 0.9800
# test loss 0.11, accuracy 0.9633
# epoch 224, loss 0.08, accuracy 0.9600
# test loss 0.13, accuracy 0.9600
# epoch 225, loss 0.08, accuracy 0.9633
# test loss 0.12, accuracy 0.9667
# epoch 226, loss 0.10, accuracy 0.9667
# test loss 0.11, accuracy 0.9633
# epoch 227, loss 0.08, accuracy 0.9700
# test loss 0.12, accuracy 0.9667
# epoch 228, loss 0.08, accuracy 0.9667
# test loss 0.11, accuracy 0.9767
# epoch 229, loss 0.08, accuracy 0.9800
# test loss 0.13, accuracy 0.9400
# epoch 230, loss 0.08, accuracy 0.9700
# test loss 0.13, accuracy 0.9400
# epoch 231, loss 0.08, accuracy 0.9700
# test loss 0.12, accuracy 0.9633
# epoch 232, loss 0.08, accuracy 0.9700
# test loss 0.11, accuracy 0.9800
# epoch 233, loss 0.08, accuracy 0.9667
# test loss 0.12, accuracy 0.9667
# epoch 234, loss 0.08, accuracy 0.9633
# test loss 0.11, accuracy 0.9633
# epoch 235, loss 0.09, accuracy 0.9600
# test loss 0.12, accuracy 0.9600
# epoch 236, loss 0.08, accuracy 0.9633
# test loss 0.12, accuracy 0.9533
# epoch 237, loss 0.07, accuracy 0.9733
# test loss 0.12, accuracy 0.9667
# epoch 238, loss 0.09, accuracy 0.9700
# test loss 0.11, accuracy 0.9667
# epoch 239, loss 0.08, accuracy 0.9667
# test loss 0.13, accuracy 0.9667
# epoch 240, loss 0.08, accuracy 0.9600
# test loss 0.11, accuracy 0.9700
# epoch 241, loss 0.08, accuracy 0.9733
# test loss 0.11, accuracy 0.9600
# epoch 242, loss 0.08, accuracy 0.9667
# test loss 0.11, accuracy 0.9667
# epoch 243, loss 0.07, accuracy 0.9733
# test loss 0.11, accuracy 0.9667
# epoch 244, loss 0.07, accuracy 0.9833
# test loss 0.16, accuracy 0.9400
# epoch 245, loss 0.09, accuracy 0.9600
# test loss 0.11, accuracy 0.9633
# epoch 246, loss 0.09, accuracy 0.9667
# test loss 0.10, accuracy 0.9733
# epoch 247, loss 0.08, accuracy 0.9667
# test loss 0.11, accuracy 0.9633
# epoch 248, loss 0.08, accuracy 0.9700
# test loss 0.12, accuracy 0.9600
# epoch 249, loss 0.08, accuracy 0.9700
# test loss 0.12, accuracy 0.9600
# epoch 250, loss 0.09, accuracy 0.9533
# test loss 0.11, accuracy 0.9567
# epoch 251, loss 0.08, accuracy 0.9633
# test loss 0.11, accuracy 0.9700
# epoch 252, loss 0.08, accuracy 0.9767
# test loss 0.12, accuracy 0.9600
# epoch 253, loss 0.08, accuracy 0.9667
# test loss 0.11, accuracy 0.9600
# epoch 254, loss 0.08, accuracy 0.9567
# test loss 0.12, accuracy 0.9633
# epoch 255, loss 0.07, accuracy 0.9700
# test loss 0.11, accuracy 0.9700
# epoch 256, loss 0.09, accuracy 0.9667
# test loss 0.11, accuracy 0.9767
# epoch 257, loss 0.08, accuracy 0.9633
# test loss 0.12, accuracy 0.9633
# epoch 258, loss 0.08, accuracy 0.9633
# test loss 0.12, accuracy 0.9633
# epoch 259, loss 0.08, accuracy 0.9833
# test loss 0.11, accuracy 0.9533
# epoch 260, loss 0.08, accuracy 0.9700
# test loss 0.11, accuracy 0.9633
# epoch 261, loss 0.08, accuracy 0.9633
# test loss 0.12, accuracy 0.9600
# epoch 262, loss 0.08, accuracy 0.9600
# test loss 0.10, accuracy 0.9700
# epoch 263, loss 0.09, accuracy 0.9633
# test loss 0.11, accuracy 0.9667
# epoch 264, loss 0.08, accuracy 0.9633
# test loss 0.11, accuracy 0.9667
# epoch 265, loss 0.07, accuracy 0.9767
# test loss 0.13, accuracy 0.9567
# epoch 266, loss 0.08, accuracy 0.9667
# test loss 0.10, accuracy 0.9600
# epoch 267, loss 0.08, accuracy 0.9667
# test loss 0.10, accuracy 0.9700
# epoch 268, loss 0.08, accuracy 0.9633
# test loss 0.11, accuracy 0.9633
# epoch 269, loss 0.08, accuracy 0.9767
# test loss 0.11, accuracy 0.9667
# epoch 270, loss 0.08, accuracy 0.9733
# test loss 0.11, accuracy 0.9633
# epoch 271, loss 0.07, accuracy 0.9767
# test loss 0.11, accuracy 0.9700
# epoch 272, loss 0.07, accuracy 0.9733
# test loss 0.11, accuracy 0.9667
# epoch 273, loss 0.07, accuracy 0.9800
# test loss 0.10, accuracy 0.9700
# epoch 274, loss 0.07, accuracy 0.9767
# test loss 0.11, accuracy 0.9767
# epoch 275, loss 0.08, accuracy 0.9700
# test loss 0.10, accuracy 0.9767
# epoch 276, loss 0.07, accuracy 0.9700
# test loss 0.12, accuracy 0.9567
# epoch 277, loss 0.08, accuracy 0.9633
# test loss 0.12, accuracy 0.9667
# epoch 278, loss 0.07, accuracy 0.9767
# test loss 0.11, accuracy 0.9667
# epoch 279, loss 0.08, accuracy 0.9667
# test loss 0.12, accuracy 0.9567
# epoch 280, loss 0.07, accuracy 0.9700
# test loss 0.14, accuracy 0.9533
# epoch 281, loss 0.08, accuracy 0.9767
# test loss 0.10, accuracy 0.9700
# epoch 282, loss 0.07, accuracy 0.9700
# test loss 0.11, accuracy 0.9633
# epoch 283, loss 0.07, accuracy 0.9700
# test loss 0.10, accuracy 0.9733
# epoch 284, loss 0.08, accuracy 0.9733
# test loss 0.10, accuracy 0.9767
# epoch 285, loss 0.08, accuracy 0.9767
# test loss 0.11, accuracy 0.9567
# epoch 286, loss 0.08, accuracy 0.9667
# test loss 0.10, accuracy 0.9700
# epoch 287, loss 0.07, accuracy 0.9633
# test loss 0.10, accuracy 0.9733
# epoch 288, loss 0.07, accuracy 0.9733
# test loss 0.13, accuracy 0.9433
# epoch 289, loss 0.07, accuracy 0.9733
# test loss 0.11, accuracy 0.9667
# epoch 290, loss 0.08, accuracy 0.9667
# test loss 0.12, accuracy 0.9467
# epoch 291, loss 0.07, accuracy 0.9700
# test loss 0.10, accuracy 0.9700
# epoch 292, loss 0.07, accuracy 0.9700
# test loss 0.10, accuracy 0.9733
# epoch 293, loss 0.07, accuracy 0.9733
# test loss 0.10, accuracy 0.9667
# epoch 294, loss 0.06, accuracy 0.9833
# test loss 0.15, accuracy 0.9400
# epoch 295, loss 0.08, accuracy 0.9733
# test loss 0.10, accuracy 0.9600
# epoch 296, loss 0.08, accuracy 0.9700
# test loss 0.10, accuracy 0.9633
# epoch 297, loss 0.08, accuracy 0.9600
# test loss 0.12, accuracy 0.9600
# epoch 298, loss 0.07, accuracy 0.9633
# test loss 0.17, accuracy 0.9433
# epoch 299, loss 0.07, accuracy 0.9733
# test loss 0.10, accuracy 0.9733
# epoch 300, loss 0.07, accuracy 0.9733
# test loss 0.10, accuracy 0.9700
