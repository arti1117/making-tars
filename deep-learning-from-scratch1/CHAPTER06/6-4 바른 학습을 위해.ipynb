# %%
from overfit_weight_decay import *
# Out:
# epoch:0, train acc:0.11333333333333333, test acc:0.0942
# epoch:1, train acc:0.11666666666666667, test acc:0.0976
# epoch:2, train acc:0.12333333333333334, test acc:0.1016
# epoch:3, train acc:0.14, test acc:0.1054
# epoch:4, train acc:0.14333333333333334, test acc:0.1151
# epoch:5, train acc:0.17333333333333334, test acc:0.1288
# epoch:6, train acc:0.18, test acc:0.1427
# epoch:7, train acc:0.18666666666666668, test acc:0.1477
# epoch:8, train acc:0.19666666666666666, test acc:0.1525
# epoch:9, train acc:0.21, test acc:0.1581
# epoch:10, train acc:0.22333333333333333, test acc:0.1699
# epoch:11, train acc:0.24666666666666667, test acc:0.1785
# epoch:12, train acc:0.25, test acc:0.1858
# epoch:13, train acc:0.27666666666666667, test acc:0.196
# epoch:14, train acc:0.3, test acc:0.205
# epoch:15, train acc:0.36666666666666664, test acc:0.226
# epoch:16, train acc:0.3333333333333333, test acc:0.2247
# epoch:17, train acc:0.34, test acc:0.2149
# ...

# %%
from overfit_dropout import *
# Out:
# train loss:2.3177120954938344
# === epoch:1, train acc:0.09, test acc:0.099 ===
# train loss:2.320403633076738
# train loss:2.3273526080497406
# train loss:2.3070983673888756
# === epoch:2, train acc:0.09, test acc:0.0981 ===
# train loss:2.3273830997846936
# train loss:2.3201348341152115
# train loss:2.31205385834257
# === epoch:3, train acc:0.09, test acc:0.0976 ===
# train loss:2.2996615073127034
# train loss:2.2942733421593546
# train loss:2.3036956994256155
# === epoch:4, train acc:0.09, test acc:0.0977 ===
# train loss:2.307103901882531
# train loss:2.3174866206876024
# train loss:2.305948732119643
# === epoch:5, train acc:0.09, test acc:0.0976 ===
# train loss:2.276599582244644
# train loss:2.315706068739585
# train loss:2.303322320712507
# === epoch:6, train acc:0.09, test acc:0.0979 ===
# train loss:2.317990974718656
# train loss:2.285233956878742
# train loss:2.301598602839235
# === epoch:7, train acc:0.09, test acc:0.0989 ===
# train loss:2.3087872325920205
# ...
