# %%
import sys
sys.path.append('..')
import numpy as np
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from attention_seq2seq import AttentionSeq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

# %%
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

# %%
vocab_size = len(char_to_id)

# %%
wordvec_size = 16
hidden_size = 256
batch_size = 128
max_epoch = 10
max_grad = 5.0

# %%
model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# %%
acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)
    
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose, is_reverse=True)
        
        
    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))
    
model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 4.08
# | 에폭 1 |  반복 21 / 351 | 시간 11[s] | 손실 3.09
# | 에폭 1 |  반복 41 / 351 | 시간 23[s] | 손실 1.90
# | 에폭 1 |  반복 61 / 351 | 시간 37[s] | 손실 1.72
# | 에폭 1 |  반복 81 / 351 | 시간 51[s] | 손실 1.46
# | 에폭 1 |  반복 101 / 351 | 시간 64[s] | 손실 1.19
# | 에폭 1 |  반복 121 / 351 | 시간 78[s] | 손실 1.14
# | 에폭 1 |  반복 141 / 351 | 시간 92[s] | 손실 1.09
# | 에폭 1 |  반복 161 / 351 | 시간 106[s] | 손실 1.06
# | 에폭 1 |  반복 181 / 351 | 시간 121[s] | 손실 1.04
# | 에폭 1 |  반복 201 / 351 | 시간 137[s] | 손실 1.03
# | 에폭 1 |  반복 221 / 351 | 시간 151[s] | 손실 1.02
# | 에폭 1 |  반복 241 / 351 | 시간 165[s] | 손실 1.02
# | 에폭 1 |  반복 261 / 351 | 시간 178[s] | 손실 1.01
# | 에폭 1 |  반복 281 / 351 | 시간 192[s] | 손실 1.00
# | 에폭 1 |  반복 301 / 351 | 시간 206[s] | 손실 1.00
# | 에폭 1 |  반복 321 / 351 | 시간 220[s] | 손실 1.00
# | 에폭 1 |  반복 341 / 351 | 시간 233[s] | 손실 1.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1978-08-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1978-08-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1978-08-11
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1978-08-11
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1978-08-11
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1978-08-11
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1978-08-11
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1978-08-11
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1978-08-11
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1978-08-11
# ---
# val acc 0.000%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 2 |  반복 21 / 351 | 시간 14[s] | 손실 1.00
# | 에폭 2 |  반복 41 / 351 | 시간 28[s] | 손실 0.99
# | 에폭 2 |  반복 61 / 351 | 시간 45[s] | 손실 0.99
# | 에폭 2 |  반복 81 / 351 | 시간 60[s] | 손실 0.99
# | 에폭 2 |  반복 101 / 351 | 시간 76[s] | 손실 0.99
# | 에폭 2 |  반복 121 / 351 | 시간 91[s] | 손실 0.99
# | 에폭 2 |  반복 141 / 351 | 시간 107[s] | 손실 0.98
# | 에폭 2 |  반복 161 / 351 | 시간 122[s] | 손실 0.98
# | 에폭 2 |  반복 181 / 351 | 시간 138[s] | 손실 0.97
# | 에폭 2 |  반복 201 / 351 | 시간 153[s] | 손실 0.95
# | 에폭 2 |  반복 221 / 351 | 시간 169[s] | 손실 0.94
# | 에폭 2 |  반복 241 / 351 | 시간 184[s] | 손실 0.90
# | 에폭 2 |  반복 261 / 351 | 시간 199[s] | 손실 0.83
# | 에폭 2 |  반복 281 / 351 | 시간 215[s] | 손실 0.74
# | 에폭 2 |  반복 301 / 351 | 시간 230[s] | 손실 0.66
# | 에폭 2 |  반복 321 / 351 | 시간 245[s] | 손실 0.58
# | 에폭 2 |  반복 341 / 351 | 시간 261[s] | 손실 0.47
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 2006-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 2007-08-09
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1983-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 2016-11-08
# ---
# val acc 51.240%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 3 |  반복 21 / 351 | 시간 14[s] | 손실 0.30
# | 에폭 3 |  반복 41 / 351 | 시간 28[s] | 손실 0.21
# | 에폭 3 |  반복 61 / 351 | 시간 43[s] | 손실 0.14
# | 에폭 3 |  반복 81 / 351 | 시간 57[s] | 손실 0.09
# | 에폭 3 |  반복 101 / 351 | 시간 71[s] | 손실 0.07
# | 에폭 3 |  반복 121 / 351 | 시간 88[s] | 손실 0.05
# | 에폭 3 |  반복 141 / 351 | 시간 105[s] | 손실 0.04
# | 에폭 3 |  반복 161 / 351 | 시간 122[s] | 손실 0.03
# | 에폭 3 |  반복 181 / 351 | 시간 141[s] | 손실 0.03
# | 에폭 3 |  반복 201 / 351 | 시간 156[s] | 손실 0.02
# | 에폭 3 |  반복 221 / 351 | 시간 170[s] | 손실 0.02
# | 에폭 3 |  반복 241 / 351 | 시간 184[s] | 손실 0.02
# | 에폭 3 |  반복 261 / 351 | 시간 198[s] | 손실 0.01
# | 에폭 3 |  반복 281 / 351 | 시간 212[s] | 손실 0.01
# | 에폭 3 |  반복 301 / 351 | 시간 226[s] | 손실 0.01
# | 에폭 3 |  반복 321 / 351 | 시간 241[s] | 손실 0.01
# | 에폭 3 |  반복 341 / 351 | 시간 255[s] | 손실 0.01
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.900%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 4 |  반복 21 / 351 | 시간 14[s] | 손실 0.01
# | 에폭 4 |  반복 41 / 351 | 시간 28[s] | 손실 0.01
# | 에폭 4 |  반복 61 / 351 | 시간 43[s] | 손실 0.01
# | 에폭 4 |  반복 81 / 351 | 시간 57[s] | 손실 0.01
# | 에폭 4 |  반복 101 / 351 | 시간 71[s] | 손실 0.01
# | 에폭 4 |  반복 121 / 351 | 시간 85[s] | 손실 0.00
# | 에폭 4 |  반복 141 / 351 | 시간 99[s] | 손실 0.01
# | 에폭 4 |  반복 161 / 351 | 시간 113[s] | 손실 0.00
# | 에폭 4 |  반복 181 / 351 | 시간 128[s] | 손실 0.00
# | 에폭 4 |  반복 201 / 351 | 시간 144[s] | 손실 0.00
# | 에폭 4 |  반복 221 / 351 | 시간 160[s] | 손실 0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17239/705427434.py in <module>
#       1 acc_list = []
#       2 for epoch in range(max_epoch):
# ----> 3     trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)
#       4
#       5     correct_num = 0
#
# ~/repo/deep-learning-from-scratch-2/common/trainer.py in fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      37
#      38                 # 기울기 구해 매개변수 갱신
# ---> 39                 loss = model.forward(batch_x, batch_t)
#      40                 model.backward()
#      41                 params, grads = remove_duplicate(model.params, model.grads)  # 공유된 가중치를 하나로 모음
#
# ~/repo/deep-learning-from-scratch-2/CHAPTER08/seq2seq.py in forward(self, xs, ts)
#     105
#     106         h = self.encoder.forward(xs)
# --> 107         score = self.decoder.forward(decoder_xs, h)
#     108         loss = self.softmax.forward(score, decoder_ts)
#     109         return loss
#
# ~/repo/deep-learning-from-scratch-2/CHAPTER08/attention_seq2seq.py in forward(self, xs, enc_hs)
#      47
#      48         out = self.embed.forward(xs)
# ---> 49         dec_hs = self.lstm.forward(out)
#      50         c = self.attention.forward(enc_hs, dec_hs)
#      51         out = np.concatenate((c, dec_hs), axis=2)
#
# ~/repo/deep-learning-from-scratch-2/common/time_layers.py in forward(self, xs)
#     191         for t in range(T):
#     192             layer = LSTM(*self.params)
# --> 193             self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
#     194             hs[:, t, :] = self.h
#     195
#
# ~/repo/deep-learning-from-scratch-2/common/time_layers.py in forward(self, x, h_prev, c_prev)
#     112         N, H = h_prev.shape
#     113
# --> 114         A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b
#     115
#     116         f = A[:, :H]
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
